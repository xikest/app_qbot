# %%
from IPython.display import Image
from bot.src_generator import StockFlw

# %%
## byte 모드 테스트
mode_binary = False

# %%
symbol="MSFT"
for plot in StockFlw().cash_plot(symbol=symbol, mode_binary=mode_binary):
    if mode_binary:
        display(Image(plot))
    else:
        plot

# %% [markdown]
# ---
