# %%
from IPython.display import Image
from bots.src_generator.src import StockFlw

# %%
## byte 모드 테스트
mode_binary = True

# %%
for plot in StockFlw(symbol="MSFT").cash_plot(mode_binary=mode_binary):
    if mode_binary:
        display(Image(plot))
    else:
        plot

# %% [markdown]
# ---
