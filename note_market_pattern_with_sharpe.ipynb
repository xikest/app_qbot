# %%
from IPython.display import Image
from bot.src_generator import MarketPattern

# %%
## byte 모드 테스트
mode_binary = False

# %%
for plot in MarketPattern().sharpe_plot(mode_binary=mode_binary):
    if mode_binary:
        display(Image(plot))
    else:
        plot

# %% [markdown]
# ---
