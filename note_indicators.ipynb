# %% [markdown]
# - MA 플랏 추가

# %% [markdown]
# ## Economic Indicators

# %%
from src_data.economic_indicators import EconomicIndicators

# %%
ei = EconomicIndicators()
ei
# Out:
# inflation
# recession
# economic_activity
# consumer_behavior
# financial_health
# total: 5

# %%
for key in ei.dict_indicators.keys():
    df = ei.requests(key, periods=10)

# %% [markdown]
# ---

# %% [markdown]
# ## Commodity Indicators

# %%
from src_data.commodity_indicators import CommodityIndicators

# %%
ci = CommodityIndicators()
ci
# Out:
# energy
# valuable
# development
# food
# total: 4

# %%
for key in ci.dict_indicators.keys():
    df = ci.requests(key)

# %% [markdown]
# ---

# %% [markdown]
# ## Stock Indicators

# %%
from src_data.stock_indicators import StockIndicators

# %%
si = StockIndicators()
si
# Out:
# sectors
# correlation_chn
# social
# contents
# hyper_scaler
# communication
# consumer_discretionary
# consumer_staples
# energy_fossil
# energy_green
# financials
# health_care
# defence
# water
# food
# semicon
# industrials
# bond
# technology
# materials
# real_estate
# utilities
# infra
# total: 23

# %%
for key in si.dict_indicators.keys():
    df = si.requests(key)

# %% [markdown]
# ## FX Indicators

# %%
from src_data.fx_indicators import FxIndicators

# %%
fi = FxIndicators()
fi
# Out:
# fx
# total: 1

# %%
for key in fi.dict_indicators.keys():
    df = fi.requests(key)

# %% [markdown]
# ## Multpl Indicators

# %%
from src_data.multpl import MultplIndicators

# %%
mi = MultplIndicators()
mi
# Out:
# shiller_ratio
# total: 1

# %%
for key in mi.dict_indicators.keys():
    df = mi.requests(key)
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 for key in mi.dict_indicators.keys():
# ----> 2     df = mi.requests(key)
#
# File ~\Documents\github\bot-on-finance_q\src_data\_abstract_indicators.py:20, in Indicators.requests(self, key_indicator, start, end, periods)
#      18 def requests(self, key_indicator: str = 'inflation', start=None, end=None, periods=None) -> DataFrame:
#      19     dict_group = self.dict_indicators.get(key_indicator, {})
# ---> 20     dict_series = {name: self._request(key=key, name=name, start=start, end=end, periods=periods) for key, name in dict_group.items()}
#      21     df = pd.DataFrame(dict_series).ffill().dropna()
#      22     return df
#
# File ~\Documents\github\bot-on-finance_q\src_data\_abstract_indicators.py:20, in <dictcomp>(.0)
# ...

# %% [markdown]
# ---
