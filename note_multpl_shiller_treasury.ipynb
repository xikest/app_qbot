# %%
from IPython.display import Image
from bot.src_generator.multpl import Multpl

# %%
## byte 모드 테스트
mode_binary = False

# %% [markdown]
# ### CAPE

# %%
for plot in Multpl().shiller_plots(mode_binary=mode_binary):
    if mode_binary:
        display(Image(plot))
    else:
        plot

# %% [markdown]
# ### Recession

# %%
for plot in Multpl().treasury_plots(mode_binary=mode_binary):
    if mode_binary:
        display(Image(plot))
    else:
        plot

# %% [markdown]
# ### Growth

# %%
for plot in Multpl().us_index_plots(mode_binary=mode_binary):
    if mode_binary:
        display(Image(plot))
    else:
        plot

# %% [markdown]
# ---
