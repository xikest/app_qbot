# %%
from IPython.display import Image
from bots.src_generator.src.multpl import Multpl

# %%
## byte 모드 테스트
mode_binary = True

# %% [markdown]
# ### CAPE

# %%
for plot in Multpl().shiller_plots(mode_binary=mode_binary):
    if mode_binary:
        display(Image(plot))
    else:
        plot

# %% [markdown]
# ### Treasury

# %%
for plot in Multpl().treasury_plots(mode_binary=mode_binary):
    if mode_binary:
        display(Image(plot))
    else:
        plot

# %% [markdown]
# ---
